# %% [markdown]
# # Dictionary Cleaning
#
# The structure of the data has two issues at this point of the process. Firstly, there are multiple classes in every file. The following code wants to collect only unique id's to exclude all describing data like professions, place names, etc. Also the "namedgraphs(KHI)" takes a huge part of the data and has no value to the further analysis. This class will also be excluded.
# Secondly, the structure is very file oriented. Every class is connected to the file in which it was stored. this relation is not relevant for further analysis of the data. Therefore the unique ids will form the new bases in the transformed data structure.

# %%
import json

dict_file = "data/entity_dump.json"

with open(dict_file, encoding="utf8") as f:
    data = json.load(f)

# %% [markdown]
# #### Analysis for double keys

# %%
length = 0
for element in list(data.keys()):
    length += len(list(data[element].keys()))

# %%
key_list = []
for element in list(data.keys()):
    for index in range(len(list(data[element].keys()))):
        key_list.append(list(data[element].keys())[index])

print(len(key_list))
# Out:
# 609534

# %%
key_dict = {}

for element in key_list:
    if element not in key_dict:
        key_dict[element] = 1
    else:
        key_dict[element] +=1

# %%
doubled_keys = {}
for element in key_dict:
    if key_dict[element] > 1:
        doubled_keys[element] = key_dict[element]

# %%
print(list(doubled_keys.keys())[:10])
# Out:
# ['78A3ECC8-66C6-3EC3-A5C7-CD6A3D2FC6DE(type)', 'EAE7042F-9813-3A08-A641-29C38FDA23DB(actor)', 'AB957EFD-FA4E-31E1-A0FC-D2A65C9A2567(type)', '328B39A4-725C-3411-ACD8-743B21C49700(type)', 'C728B7D3-D346-3F4B-92A3-EF87ED5F8BE4(type)', '241030FF-AC0E-3B4F-BCB1-F0BBEE3CBA66(place)', '71D1C456-088F-3C01-89A7-4B2ED119E73E(type)', '5E3A8561-554B-3215-A2F1-E5258EF166E4(type)', 'F6197719-FC31-3AE5-838D-AF4B69A37C72(type)', '48378153-A40D-3533-9CD7-EF6D02595E0C(type)']

# %%
for element in list(data.keys()):
    if "B3D29692-6F9F-30CE-9E42-558C85BE3301(technique)" in list(data[element].keys()):
        print(element)
# Out:
# artworks_lvl2/formated-part_3414_cleaned.trig
# artworks_lvl2/formated-part_3406_cleaned.trig
# artworks_lvl2/formated-part_3367_cleaned.trig
# artworks_lvl2/formated-part_3085_cleaned.trig
# artworks_lvl2/formated-part_3107_cleaned.trig
# artworks_lvl2/formated-part_3463_cleaned.trig
# artworks_lvl2/formated-part_3421_cleaned.trig
# artworks_lvl2/formated-part_3358_cleaned.trig
# artworks_lvl2/formated-part_3097_cleaned.trig
# artworks_lvl2/formated-part_3379_cleaned.trig
# artworks_lvl2/formated-part_3507_cleaned.trig
# artworks_lvl2/formated-part_3401_cleaned.trig
# artworks_lvl2/formated-part_3359_cleaned.trig
# artworks_lvl2/formated-part_3255_cleaned.trig
# artworks_lvl2/formated-part_3202_cleaned.trig
# artworks/formated-part_3356_cleaned.trig
# artworks/formated-part_3366_cleaned.trig
# artworks/formated-part_3167_cleaned.trig
# artworks/formated-part_3354_cleaned.trig
# artworks/formated-part_3126_cleaned.trig
# artworks/formated-part_3380_cleaned.trig
# artworks/formated-part_3250_cleaned.trig
# artworks/formated-part_3106_cleaned.trig
# artworks/formated-part_3306_cleaned.trig
# artworks/formated-part_3252_cleaned.trig
# artworks/formated-part_3249_cleaned.trig
# artworks/formated-part_3419_cleaned.trig
# artworks/formated-part_3230_cleaned.trig
# artworks/formated-part_3071_cleaned.trig
# artworks/formated-part_3203_cleaned.trig
# artworks/formated-part_3319_cleaned.trig
# artworks/formated-part_3352_cleaned.trig
# artworks/formated-part_3333_cleaned.trig
# artworks/formated-part_3414_cleaned.trig
# artworks/formated-part_3083_cleaned.trig
# artworks/formated-part_3479_cleaned.trig
# artworks/formated-part_3261_cleaned.trig
# artworks/formated-part_3245_cleaned.trig
# artworks/formated-part_3163_cleaned.trig
# artworks/formated-part_3241_cleaned.trig
# artworks/formated-part_3303_cleaned.trig
# artworks/formated-part_3044_cleaned.trig
# artworks/formated-part_3093_cleaned.trig
# artworks/formated-part_3234_cleaned.trig
# artworks/formated-part_3109_cleaned.trig
# artworks/formated-part_3491_cleaned.trig
# artworks/formated-part_3374_cleaned.trig
# artworks/formated-part_3423_cleaned.trig
# artworks/formated-part_3289_cleaned.trig
# artworks/formated-part_3275_cleaned.trig
# artworks/formated-part_3096_cleaned.trig
# artworks/formated-part_3309_cleaned.trig
# artworks/formated-part_3229_cleaned.trig
# artworks/formated-part_3312_cleaned.trig
# artworks/formated-part_3053_cleaned.trig
# artworks/formated-part_3406_cleaned.trig
# artworks/formated-part_3156_cleaned.trig
# artworks/formated-part_3145_cleaned.trig
# artworks/formated-part_3510_cleaned.trig
# artworks/formated-part_3512_cleaned.trig
# artworks/formated-part_3218_cleaned.trig
# artworks/formated-part_3281_cleaned.trig
# artworks/formated-part_3196_cleaned.trig
# artworks/formated-part_3111_cleaned.trig
# artworks/formated-part_3048_cleaned.trig
# artworks/formated-part_3385_cleaned.trig
# artworks/formated-part_3154_cleaned.trig
# artworks/formated-part_3192_cleaned.trig
# artworks/formated-part_3317_cleaned.trig
# artworks/formated-part_3207_cleaned.trig
# artworks/formated-part_3519_cleaned.trig
# artworks/formated-part_3165_cleaned.trig
# artworks/formated-part_3277_cleaned.trig
# artworks/formated-part_3175_cleaned.trig
# artworks/formated-part_3458_cleaned.trig
# artworks/formated-part_3363_cleaned.trig
# artworks/formated-part_3459_cleaned.trig
# artworks/formated-part_3388_cleaned.trig
# artworks/formated-part_3117_cleaned.trig
# artworks/formated-part_3108_cleaned.trig
# artworks/formated-part_3367_cleaned.trig
# artworks/formated-part_3260_cleaned.trig
# artworks/formated-part_3399_cleaned.trig
# artworks/formated-part_3233_cleaned.trig
# artworks/formated-part_3179_cleaned.trig
# artworks/formated-part_3176_cleaned.trig
# artworks/formated-part_3473_cleaned.trig
# artworks/formated-part_3297_cleaned.trig
# artworks/formated-part_3065_cleaned.trig
# artworks/formated-part_3086_cleaned.trig
# artworks/formated-part_3107_cleaned.trig
# artworks/formated-part_3503_cleaned.trig
# artworks/formated-part_3461_cleaned.trig
# artworks/formated-part_3377_cleaned.trig
# artworks/formated-part_3382_cleaned.trig
# artworks/formated-part_3248_cleaned.trig
# artworks/formated-part_3276_cleaned.trig
# artworks/formated-part_3067_cleaned.trig
# artworks/formated-part_3318_cleaned.trig
# artworks/formated-part_3474_cleaned.trig
# artworks/formated-part_3124_cleaned.trig
# artworks/formated-part_3087_cleaned.trig
# artworks/formated-part_3136_cleaned.trig
# artworks/formated-part_3122_cleaned.trig
# artworks/formated-part_3487_cleaned.trig
# artworks/formated-part_3301_cleaned.trig
# artworks/formated-part_3450_cleaned.trig
# artworks/formated-part_3469_cleaned.trig
# artworks/formated-part_3378_cleaned.trig
# artworks/formated-part_3140_cleaned.trig
# artworks/formated-part_3284_cleaned.trig
# artworks/formated-part_3373_cleaned.trig
# artworks/formated-part_3104_cleaned.trig
# artworks/formated-part_3049_cleaned.trig
# artworks/formated-part_3142_cleaned.trig
# artworks/formated-part_3383_cleaned.trig
# artworks/formated-part_3412_cleaned.trig
# artworks/formated-part_3146_cleaned.trig
# artworks/formated-part_3120_cleaned.trig
# artworks/formated-part_3095_cleaned.trig
# artworks/formated-part_3242_cleaned.trig
# artworks/formated-part_3371_cleaned.trig
# artworks/formated-part_3387_cleaned.trig
# artworks/formated-part_3237_cleaned.trig
# artworks/formated-part_3433_cleaned.trig
# artworks/formated-part_3506_cleaned.trig
# artworks/formated-part_3166_cleaned.trig
# artworks/formated-part_3287_cleaned.trig
# artworks/formated-part_3058_cleaned.trig
# artworks/formated-part_3082_cleaned.trig
# artworks/formated-part_3358_cleaned.trig
# artworks/formated-part_3159_cleaned.trig
# artworks/formated-part_3116_cleaned.trig
# artworks/formated-part_3376_cleaned.trig
# artworks/formated-part_3351_cleaned.trig
# artworks/formated-part_3084_cleaned.trig
# artworks/formated-part_3515_cleaned.trig
# artworks/formated-part_3362_cleaned.trig
# artworks/formated-part_3282_cleaned.trig
# artworks/formated-part_3268_cleaned.trig
# artworks/formated-part_3047_cleaned.trig
# artworks/formated-part_3403_cleaned.trig
# artworks/formated-part_3501_cleaned.trig
# artworks/formated-part_3477_cleaned.trig
# artworks/formated-part_3272_cleaned.trig
# artworks/formated-part_3291_cleaned.trig
# artworks/formated-part_3330_cleaned.trig
# artworks/formated-part_3405_cleaned.trig
# artworks/formated-part_3204_cleaned.trig
# artworks/formated-part_3097_cleaned.trig
# artworks/formated-part_3516_cleaned.trig
# artworks/formated-part_3316_cleaned.trig
# artworks/formated-part_3481_cleaned.trig
# artworks/formated-part_3379_cleaned.trig
# artworks/formated-part_3144_cleaned.trig
# artworks/formated-part_3152_cleaned.trig
# artworks/formated-part_3222_cleaned.trig
# artworks/formated-part_3199_cleaned.trig
# artworks/formated-part_3298_cleaned.trig
# artworks/formated-part_3256_cleaned.trig
# artworks/formated-part_3443_cleaned.trig
# artworks/formated-part_3300_cleaned.trig
# artworks/formated-part_3360_cleaned.trig
# artworks/formated-part_3077_cleaned.trig
# artworks/formated-part_3045_cleaned.trig
# artworks/formated-part_3128_cleaned.trig
# artworks/formated-part_3486_cleaned.trig
# artworks/formated-part_3286_cleaned.trig
# artworks/formated-part_3263_cleaned.trig
# artworks/formated-part_3472_cleaned.trig
# artworks/formated-part_3427_cleaned.trig
# artworks/formated-part_3055_cleaned.trig
# artworks/formated-part_3464_cleaned.trig
# artworks/formated-part_3507_cleaned.trig
# artworks/formated-part_3164_cleaned.trig
# artworks/formated-part_3081_cleaned.trig
# artworks/formated-part_3112_cleaned.trig
# artworks/formated-part_3118_cleaned.trig
# artworks/formated-part_3099_cleaned.trig
# artworks/formated-part_3063_cleaned.trig
# artworks/formated-part_3453_cleaned.trig
# artworks/formated-part_3269_cleaned.trig
# artworks/formated-part_3444_cleaned.trig
# artworks/formated-part_3392_cleaned.trig
# artworks/formated-part_3488_cleaned.trig
# artworks/formated-part_3210_cleaned.trig
# artworks/formated-part_3184_cleaned.trig
# artworks/formated-part_3508_cleaned.trig
# artworks/formated-part_3441_cleaned.trig
# artworks/formated-part_3313_cleaned.trig
# artworks/formated-part_3353_cleaned.trig
# artworks/formated-part_3386_cleaned.trig
# artworks/formated-part_3228_cleaned.trig
# artworks/formated-part_3061_cleaned.trig
# artworks/formated-part_3271_cleaned.trig
# artworks/formated-part_3231_cleaned.trig
# artworks/formated-part_3119_cleaned.trig
# artworks/formated-part_3220_cleaned.trig
# artworks/formated-part_3188_cleaned.trig
# artworks/formated-part_3123_cleaned.trig
# artworks/formated-part_3043_cleaned.trig
# artworks/formated-part_3227_cleaned.trig
# artworks/formated-part_3050_cleaned.trig
# artworks/formated-part_3418_cleaned.trig
# artworks/formated-part_3285_cleaned.trig
# artworks/formated-part_3505_cleaned.trig
# artworks/formated-part_3468_cleaned.trig
# artworks/formated-part_3324_cleaned.trig
# artworks/formated-part_3212_cleaned.trig
# artworks/formated-part_3051_cleaned.trig
# artworks/formated-part_3101_cleaned.trig
# artworks/formated-part_3288_cleaned.trig
# artworks/formated-part_3345_cleaned.trig
# artworks/formated-part_3442_cleaned.trig
# artworks/formated-part_3177_cleaned.trig
# artworks/formated-part_3384_cleaned.trig
# artworks/formated-part_3331_cleaned.trig
# artworks/formated-part_3238_cleaned.trig
# artworks/formated-part_3155_cleaned.trig
# artworks/formated-part_3466_cleaned.trig
# artworks/formated-part_3445_cleaned.trig
# artworks/formated-part_3402_cleaned.trig
# artworks/formated-part_3490_cleaned.trig
# artworks/formated-part_3143_cleaned.trig
# artworks/formated-part_3105_cleaned.trig
# artworks/formated-part_3413_cleaned.trig
# artworks/formated-part_3326_cleaned.trig
# artworks/formated-part_3431_cleaned.trig
# artworks/formated-part_3133_cleaned.trig
# artworks/formated-part_3215_cleaned.trig
# artworks/formated-part_3160_cleaned.trig
# artworks/formated-part_3447_cleaned.trig
# artworks/formated-part_3259_cleaned.trig
# artworks/formated-part_3091_cleaned.trig
# artworks/formated-part_3455_cleaned.trig
# artworks/formated-part_3072_cleaned.trig
# artworks/formated-part_3134_cleaned.trig
# artworks/formated-part_3359_cleaned.trig
# artworks/formated-part_3102_cleaned.trig
# artworks/formated-part_3478_cleaned.trig
# artworks/formated-part_3064_cleaned.trig
# artworks/formated-part_3446_cleaned.trig
# artworks/formated-part_3211_cleaned.trig
# artworks/formated-part_3426_cleaned.trig
# artworks/formated-part_3293_cleaned.trig
# artworks/formated-part_3299_cleaned.trig
# artworks/formated-part_3350_cleaned.trig
# artworks/formated-part_3449_cleaned.trig
# artworks/formated-part_3411_cleaned.trig
# artworks/formated-part_3150_cleaned.trig
# artworks/formated-part_3251_cleaned.trig
# artworks/formated-part_3178_cleaned.trig
# artworks/formated-part_3115_cleaned.trig
# artworks/formated-part_3114_cleaned.trig
# artworks/formated-part_3292_cleaned.trig
# artworks/formated-part_3347_cleaned.trig
# artworks/formated-part_3315_cleaned.trig
# artworks/formated-part_3057_cleaned.trig
# artworks/formated-part_3304_cleaned.trig
# artworks/formated-part_3171_cleaned.trig
# artworks/formated-part_3320_cleaned.trig
# artworks/formated-part_3279_cleaned.trig
# artworks/formated-part_3370_cleaned.trig
# artworks/formated-part_3310_cleaned.trig
# artworks/formated-part_3090_cleaned.trig
# artworks/formated-part_3322_cleaned.trig
# artworks/formated-part_3094_cleaned.trig
# artworks/formated-part_3369_cleaned.trig
# artworks/formated-part_3390_cleaned.trig
# artworks/formated-part_3151_cleaned.trig
# artworks/formated-part_3139_cleaned.trig
# artworks/formated-part_3074_cleaned.trig
# artworks/formated-part_3438_cleaned.trig
# artworks/formated-part_3153_cleaned.trig
# artworks/formated-part_3355_cleaned.trig
# artworks/formated-part_3226_cleaned.trig
# artworks/formated-part_3132_cleaned.trig
# artworks/formated-part_3482_cleaned.trig
# artworks/formated-part_3295_cleaned.trig
# artworks/formated-part_3408_cleaned.trig
# artworks/formated-part_3513_cleaned.trig
# artworks/formated-part_3381_cleaned.trig
# artworks/formated-part_3205_cleaned.trig
# artworks/formated-part_3100_cleaned.trig
# artworks/formated-part_3170_cleaned.trig
# artworks/formated-part_3243_cleaned.trig
# artworks/formated-part_3062_cleaned.trig
# artworks/formated-part_3244_cleaned.trig
# artworks/formated-part_3209_cleaned.trig
# artworks/formated-part_3428_cleaned.trig
# artworks/formated-part_3264_cleaned.trig
# artworks/formated-part_3500_cleaned.trig
# artworks/formated-part_3465_cleaned.trig
# artworks/formated-part_3410_cleaned.trig
# artworks/formated-part_3398_cleaned.trig
# artworks/formated-part_3161_cleaned.trig
# artworks/formated-part_3437_cleaned.trig
# artworks/formated-part_3068_cleaned.trig
# artworks/formated-part_3509_cleaned.trig
# artworks/formated-part_3070_cleaned.trig
# artworks/formated-part_3187_cleaned.trig
# artworks/formated-part_3492_cleaned.trig
# artworks/formated-part_3417_cleaned.trig
# artworks/formated-part_3255_cleaned.trig
# artworks/formated-part_3391_cleaned.trig
# artworks/formated-part_3311_cleaned.trig
# artworks/formated-part_3240_cleaned.trig
# artworks/formated-part_3365_cleaned.trig
# artworks/formated-part_3157_cleaned.trig
# artworks/formated-part_3429_cleaned.trig
# artworks/formated-part_3518_cleaned.trig
# artworks/formated-part_3158_cleaned.trig
# artworks/formated-part_3368_cleaned.trig
# artworks/formated-part_3502_cleaned.trig
# artworks/formated-part_3397_cleaned.trig
# artworks/formated-part_3335_cleaned.trig
# artworks/formated-part_3125_cleaned.trig
# artworks/formated-part_3270_cleaned.trig
# artworks/formated-part_3168_cleaned.trig
# artworks/formated-part_3452_cleaned.trig
# artworks/formated-part_3060_cleaned.trig
# artworks/formated-part_3329_cleaned.trig
# artworks/formated-part_3325_cleaned.trig
# artworks/formated-part_3198_cleaned.trig
# artworks/formated-part_3169_cleaned.trig
# artworks/formated-part_3201_cleaned.trig
# artworks/formated-part_3290_cleaned.trig
# artworks/formated-part_3172_cleaned.trig
# artworks/formated-part_3342_cleaned.trig
# artworks/formated-part_3041_cleaned.trig
# artworks/formated-part_3221_cleaned.trig
# artworks/formated-part_3484_cleaned.trig
# artworks/formated-part_3432_cleaned.trig
# artworks/formated-part_3075_cleaned.trig
# artworks/formated-part_3073_cleaned.trig
# artworks/formated-part_3069_cleaned.trig
# artworks/formated-part_3173_cleaned.trig
# artworks/formated-part_3308_cleaned.trig
# artworks/formated-part_3470_cleaned.trig
# artworks/formated-part_3190_cleaned.trig
# artworks/formated-part_3296_cleaned.trig
# artworks/formated-part_3489_cleaned.trig
# artworks/formated-part_3052_cleaned.trig
# artworks/formated-part_3239_cleaned.trig
# artworks/formated-part_3174_cleaned.trig
# artworks/formated-part_3197_cleaned.trig
# artworks/formated-part_3149_cleaned.trig
# artworks/formated-part_3098_cleaned.trig
# artworks/formated-part_3247_cleaned.trig
# artworks/formated-part_3307_cleaned.trig
# artworks/formated-part_3498_cleaned.trig
# artworks/formated-part_3202_cleaned.trig
# artworks/formated-part_3130_cleaned.trig
# artworks/formated-part_3416_cleaned.trig
# artworks/formated-part_3135_cleaned.trig
# artworks/formated-part_3110_cleaned.trig
# artworks/formated-part_3113_cleaned.trig
# artworks/formated-part_3364_cleaned.trig
# artworks/formated-part_3471_cleaned.trig

# %% [markdown]
# #### Transformation
#
# Changing the hierarchy and puting all classes in one dict

# %%
restructured_data = {}

for key in list(data.keys()):
    for key_2 in list(data[key].keys()):
        restructured_data[key_2] = data[key][key_2]

# %%
for key in list(restructured_data.keys()):
    for element in range(len(restructured_data[key])):
        for element_2 in range(len(restructured_data[key][element])):
            if type(restructured_data[key][element][element_2]) is list:
                for element_3 in range(len(restructured_data[key][element][element_2])):
                    restructured_data[key][element][element_2][element_3] = restructured_data[key][element][element_2][element_3].replace(">(", "(")

# %%
print(restructured_data[list(restructured_data.keys())[0]])

print(len(list(restructured_data.keys())))
# Out:
# [[['U8B6Y4YM(type)', 'Namedgraph(custom)'], ['has_provider(custom)', 'KHI(source)']], [['78A3ECC8-66C6-3EC3-A5C7-CD6A3D2FC6DE(type)', 'E55_Type(cidoc-crm)'], {'Label': 'rechteckig'}, ['P2_has_type(cidoc-crm)', 'C57BB460-B736-3F52-8867-FFCF908C12B6(type)'], ['P67i_is_referred_to_by(cidoc-crm)', 'U8B6Y4YM(type)'], ['has_provider(custom)', 'KHI(source)']]]
# 237879

# %%
# excluding the unwanted "namedgraphs" class

restructured_data.pop("namedgraphs(KHI)")
# Out:
# [[['02552804(actor)', 'Namedgraph(custom)']],
#  [['07601433%2CT%2C002%2CT%2C001%2CT%2C001(work)', 'Namedgraph(custom)']],
#  [['TOOGTZOY(type)', 'Namedgraph(custom)']],
#  [['TNZJPOA2(type)', 'Namedgraph(custom)']],
#  [['1H84RLO2(type)', 'Namedgraph(custom)']],
#  [['namedgraphs(KHI)', 'SourceNamedgraph(custom)'],
#   ['consists_of(custom)', '07601433%2CT%2C002%2CT%2C001%2CT%2C001(work)']]]

# %%
print(list(restructured_data.keys())[:3])
# Out:
# ['78A3ECC8-66C6-3EC3-A5C7-CD6A3D2FC6DE(type)', 'EAE7042F-9813-3A08-A641-29C38FDA23DB(actor)', 'AB957EFD-FA4E-31E1-A0FC-D2A65C9A2567(type)']

# %% [markdown]
# #### Key statistics

# %%
key_tuple = ()

for key in restructured_data.keys():
    key_tuple = key_tuple + (key,)
"""
for element in data:
    for key in data[element].keys():
        key_tuple = key_tuple + (key,)
"""
# Out:
# '\nfor element in data:\n    for key in data[element].keys():\n        key_tuple = key_tuple + (key,)\n'

# %%
category = key_tuple[0].replace(")", "").split("(")[1]
category
# Out:
# 'type'

# %%
category_stats_dict = {}
for index in range(len(key_tuple)):
    category = key_tuple[index].replace(")", "").split("(")[1]
    if category not in category_stats_dict:
        category_stats_dict[category] = {"Count":1, "IDs":[key_tuple[index]]}
    else:
        category_stats_dict[category]["Count"] += 1
        category_stats_dict[category]["IDs"].append(key_tuple[index])

# %%
for element in category_stats_dict:
    print("Category:\t{}\nCount:\t{}\nExamples:\t{}\n\n".format(element, category_stats_dict[element]["Count"], category_stats_dict[element]["IDs"][:5]))
# Out:
# Category:	type
# Count:	34919
# Examples:	['78A3ECC8-66C6-3EC3-A5C7-CD6A3D2FC6DE(type)', 'AB957EFD-FA4E-31E1-A0FC-D2A65C9A2567(type)', '328B39A4-725C-3411-ACD8-743B21C49700(type)', 'C728B7D3-D346-3F4B-92A3-EF87ED5F8BE4(type)', '71D1C456-088F-3C01-89A7-4B2ED119E73E(type)']
#
#
# Category:	actor
# Count:	16011
# Examples:	['EAE7042F-9813-3A08-A641-29C38FDA23DB(actor)', 'F4B7CF34-0AF4-36B4-82C2-11E56AB87103(actor)', '02552782(actor)', '07600210(actor)', '00086500(actor)']
#
#
# Category:	place
# Count:	9105
# Examples:	['241030FF-AC0E-3B4F-BCB1-F0BBEE3CBA66(place)', '946DD00F-13F3-342B-999D-9C5874DC5DE4(place)', '4A887B8A-68AC-39B0-8D9D-027BDDEDB06B(place)', '2996325D-BD5E-3FB0-8815-F546ADB971AD(place)', '90AE43FF-9F61-3FCA-8E00-9FE49999A499(place)']
#
#
# Category:	work
# Count:	98948
# Examples:	['07874792(work)', '07874803(work)', '07874807(work)', '07960073%2CT%2C011%2CT(work)', '07874809(work)']
#
#
# Category:	material
# Count:	607
# Examples:	['B6D5D085-72FC-3D9C-8D9D-2CBEA3DB4D07(material)', '1D4D1728-9C35-39A6-912E-620890392F9A(material)', '865D51F4-A23F-3B19-B02C-944B749D0DE9(material)', '76915B47-CACF-35A5-981D-6885810243A1(material)', 'FE3484B7-804C-3814-87E8-873F1A8F2740(material)']
#
#
# Category:	technique
# Count:	260
# Examples:	['133E91CD-B191-3790-8783-72212D7AF6B2(technique)', '85A592D2-AB84-3A39-93B4-B0B7C2D5B313(technique)', '0CADA2A5-7D9B-34B9-8F0E-DFEDA835F585(technique)', '0BC826AE-AD83-3E06-AC03-C9D2D23CAD83(technique)', '2BE6ED3F-8451-33DB-BDE1-1E78469255AC(technique)']
#
#
# Category:	collection
# Count:	121
# Examples:	['9FCA7C02-5248-3098-A421-900138DA0BDE(collection)', 'A7BBE344-528E-3511-B587-6E87B96C4A99(collection)', '13B7DFE3-5766-3506-A6B2-9019BE937DD1(collection)', 'B4F890B6-C016-3536-81A3-9886BCB706E6(collection)', '79C18901-5ED2-3B18-904C-2E399DBA6144(collection)']
#
#
# Category:	negative
# Count:	31709
# Examples:	['1561%20Artini(negative)', '1430%20Artini(negative)', '12617(negative)', '24679%20Laurati(negative)', '1433%20Artini(negative)']
#
#
# Category:	photo
# Count:	45192
# Examples:	['fln0419237z_p(photo)', 'fln0320499z_p(photo)', 'fln0609885y_p(photo)', 'fln0320501z_p(photo)', 'fld0001520z_p(photo)']
#
#
# Category:	55862
# Count:	1
# Examples:	['34(55862)']
#
#
# Category:	55864
# Count:	1
# Examples:	['36(55864)']
#
#
# Category:	746
# Count:	4
# Examples:	['61(746)', '63(746)', '68(746)', '60(746)']
#
#
# Category:	320
# Count:	1
# Examples:	['88(320)']
#
#
# Category:	318
# Count:	1
# Examples:	['88(318)']
#
#
# Category:	332
# Count:	1
# Examples:	['88(332)']
#
#
# Category:	55863
# Count:	1
# Examples:	['35(55863)']
#
#
# Category:	55825
# Count:	6
# Examples:	['1(55825)', '6(55825)', '4(55825)', '3(55825)', '16(55825)']
#
#
# Category:	319
# Count:	1
# Examples:	['88(319)']
#
#
# Category:	4
# Count:	3
# Examples:	['col(4)', '28(4)', '39(4)']
#
#
# Category:	335
# Count:	1
# Examples:	['88(335)']
#
#
# Category:	55865
# Count:	1
# Examples:	['37(55865)']
#
#
# Category:	56412
# Count:	3
# Examples:	['16(56412)', '14(56412)', '18(56412)']
#
#
# Category:	56287
# Count:	2
# Examples:	['15(56287)', '18(56287)']
#
#
# Category:	56204
# Count:	5
# Examples:	['8(56204)', '13(56204)', '23(56204)', '20(56204)', '11(56204)']
#
#
# Category:	56423
# Count:	3
# Examples:	['12(56423)', '10(56423)', '13(56423)']
#
#
# Category:	56284
# Count:	2
# Examples:	['5(56284)', '2(56284)']
#
#
# Category:	56439
# Count:	3
# Examples:	['12(56439)', '13(56439)', '10(56439)']
#
#
# Category:	55826
# Count:	2
# Examples:	['15(55826)', '18(55826)']
#
#
# Category:	56409
# Count:	1
# Examples:	['4(56409)']
#
#
# Category:	55798
# Count:	1
# Examples:	['col(55798)']
#
#
# Category:	56230
# Count:	4
# Examples:	['5(56230)', '29(56230)', '25(56230)', '3(56230)']
#
#
# Category:	742
# Count:	6
# Examples:	['24(742)', '18(742)', '15(742)', '17(742)', '13(742)']
#
#
# Category:	56413
# Count:	3
# Examples:	['1(56413)', '3(56413)', '4(56413)']
#
#
# Category:	744
# Count:	3
# Examples:	['47(744)', '41(744)', '45(744)']
#
#
# Category:	15064
# Count:	2
# Examples:	['6(15064)', '12(15064)']
#
#
# Category:	8
# Count:	4
# Examples:	['col(8)', '11A(8)', '12A(8)', '31(8)']
#
#
# Category:	56431
# Count:	3
# Examples:	['10(56431)', '12(56431)', '13(56431)']
#
#
# Category:	56429
# Count:	3
# Examples:	['3(56429)', '1(56429)', '4(56429)']
#
#
# Category:	56414
# Count:	2
# Examples:	['9(56414)', '7(56414)']
#
#
# Category:	56440
# Count:	3
# Examples:	['17(56440)', '14(56440)', '16(56440)']
#
#
# Category:	5
# Count:	6
# Examples:	['col(5)', '3a(5)', '29a(5)', '25a(5)', '11a(5)']
#
#
# Category:	56411
# Count:	3
# Examples:	['12(56411)', '10(56411)', '13(56411)']
#
#
# Category:	55827
# Count:	3
# Examples:	['9(55827)', '6(55827)', '3(55827)']
#
#
# Category:	56193
# Count:	1
# Examples:	['A(56193)']
#
#
# Category:	56425
# Count:	3
# Examples:	['1(56425)', '3(56425)', '4(56425)']
#
#
# Category:	56424
# Count:	3
# Examples:	['16(56424)', '14(56424)', '17(56424)']
#
#
# Category:	2
# Count:	5
# Examples:	['col(2)', '34(2)', '26A(2)', '27A(2)', '32%20A(2)']
#
#
# Category:	56427
# Count:	3
# Examples:	['13(56427)', '10(56427)', '12(56427)']
#
#
# Category:	56417
# Count:	3
# Examples:	['1(56417)', '3(56417)', '4(56417)']
#
#
# Category:	56410
# Count:	2
# Examples:	['6(56410)', '9(56410)']
#
#
# Category:	3
# Count:	4
# Examples:	['col(3)', '9%20A(3)', '29A(3)', '36A(3)']
#
#
# Category:	743
# Count:	3
# Examples:	['31(743)', '36(743)', '32(743)']
#
#
# Category:	56286
# Count:	1
# Examples:	['14(56286)']
#
#
# Category:	56419
# Count:	3
# Examples:	['12(56419)', '10(56419)', '13(56419)']
#
#
# Category:	56407
# Count:	3
# Examples:	['12(56407)', '13(56407)', '10(56407)']
#
#
# Category:	745
# Count:	2
# Examples:	['53(745)', '56(745)']
#
#
# Category:	55823
# Count:	4
# Examples:	['1(55823)', '9(55823)', '4(55823)', '3(55823)']
#
#
# Category:	56430
# Count:	3
# Examples:	['9(56430)', '7(56430)', '6(56430)']
#
#
# Category:	55828
# Count:	2
# Examples:	['12(55828)', '13(55828)']
#
#
# Category:	741
# Count:	4
# Examples:	['4(741)', '51%20%2830%29(741)', '51%20%2829%29(741)', '3(741)']
#
#
# Category:	6
# Count:	1
# Examples:	['col(6)']
#
#
# Category:	968
# Count:	1
# Examples:	['66(968)']
#
#
# Category:	31076
# Count:	2
# Examples:	['33(31076)', '32(31076)']
#
#
# Category:	31052
# Count:	6
# Examples:	['231(31052)', '232(31052)', '230(31052)', '233(31052)', '234(31052)']
#
#
# Category:	31015
# Count:	3
# Examples:	['59%20Bazzechi(31015)', '61%20Bazzechi(31015)', '60%20Bazzechi(31015)']
#
#
# Category:	762
# Count:	3
# Examples:	['11(762)', '10(762)', '9(762)']
#
#
# Category:	763
# Count:	4
# Examples:	['22(763)', '19(763)', '15(763)', '21(763)']
#
#
# Category:	15325
# Count:	10
# Examples:	['46(15325)', '42(15325)', '48(15325)', '52(15325)', '49(15325)']
#
#
# Category:	10
# Count:	3
# Examples:	['37(10)', 'col(10)', '38(10)']
#
#
# Category:	56394
# Count:	3
# Examples:	['13(56394)', '11(56394)', '10(56394)']
#
#
# Category:	1
# Count:	3
# Examples:	['37(1)', 'col(1)', '20A(1)']
#
#
# Category:	31012
# Count:	1
# Examples:	['47%20Bazzechi(31012)']
#
#
# Category:	31010
# Count:	1
# Examples:	['42%20Bazzechi(31010)']
#
#
# Category:	56397
# Count:	3
# Examples:	['6(56397)', '7(56397)', '9(56397)']
#
#
# Category:	31004
# Count:	2
# Examples:	['20%20Bazzechi(31004)', '19%20Bazzechi(31004)']
#
#
# Category:	31013
# Count:	2
# Examples:	['53%20Bazzechi(31013)', '51%20Bazzechi(31013)']
#
#
# Category:	52333
# Count:	1
# Examples:	['A(52333)']
#
#
# Category:	55845
# Count:	1
# Examples:	['17(55845)']
#
#
# Category:	55849
# Count:	1
# Examples:	['21(55849)']
#
#
# Category:	55876
# Count:	1
# Examples:	['48(55876)']
#
#
# Category:	55852
# Count:	1
# Examples:	['24(55852)']
#
#
# Category:	55855
# Count:	1
# Examples:	['27(55855)']
#
#
# Category:	55839
# Count:	1
# Examples:	['11(55839)']
#
#
# Category:	55859
# Count:	1
# Examples:	['31(55859)']
#
#
# Category:	55833
# Count:	1
# Examples:	['5(55833)']
#
#
# Category:	55872
# Count:	1
# Examples:	['44(55872)']
#
#
# Category:	55903
# Count:	1
# Examples:	['75(55903)']
#
#
# Category:	55886
# Count:	1
# Examples:	['58(55886)']
#
#
# Category:	55890
# Count:	1
# Examples:	['62(55890)']
#
#
# Category:	55831
# Count:	1
# Examples:	['3(55831)']
#
#
# Category:	55836
# Count:	1
# Examples:	['8(55836)']
#
#
# Category:	55902
# Count:	1
# Examples:	['74(55902)']
#
#
# Category:	55844
# Count:	1
# Examples:	['16(55844)']
#
#
# Category:	55869
# Count:	1
# Examples:	['41(55869)']
#
#
# Category:	55888
# Count:	1
# Examples:	['60(55888)']
#
#
# Category:	55870
# Count:	1
# Examples:	['42(55870)']
#
#
# Category:	55887
# Count:	1
# Examples:	['59(55887)']
#
#
# Category:	55880
# Count:	1
# Examples:	['52(55880)']
#
#
# Category:	55861
# Count:	1
# Examples:	['33(55861)']
#
#
# Category:	55896
# Count:	1
# Examples:	['68(55896)']
#
#
# Category:	55834
# Count:	1
# Examples:	['6(55834)']
#
#
# Category:	55879
# Count:	1
# Examples:	['51(55879)']
#
#
# Category:	55897
# Count:	1
# Examples:	['69(55897)']
#
#
# Category:	55900
# Count:	1
# Examples:	['72(55900)']
#
#
# Category:	55841
# Count:	1
# Examples:	['13(55841)']
#
#
# Category:	55889
# Count:	1
# Examples:	['61(55889)']
#
#
# Category:	55842
# Count:	1
# Examples:	['14(55842)']
#
#
# Category:	55901
# Count:	1
# Examples:	['73(55901)']
#
#
# Category:	55851
# Count:	1
# Examples:	['23(55851)']
#
#
# Category:	55860
# Count:	1
# Examples:	['32(55860)']
#
#
# Category:	55898
# Count:	1
# Examples:	['70(55898)']
#
#
# Category:	55857
# Count:	1
# Examples:	['29(55857)']
#
#
# Category:	55850
# Count:	1
# Examples:	['22(55850)']
#
#
# Category:	55830
# Count:	1
# Examples:	['2(55830)']
#
#
# Category:	55858
# Count:	1
# Examples:	['30(55858)']
#
#
# Category:	55899
# Count:	1
# Examples:	['71(55899)']
#
#
# Category:	55843
# Count:	1
# Examples:	['15(55843)']
#
#
# Category:	55878
# Count:	1
# Examples:	['50(55878)']
#
#
# Category:	55885
# Count:	1
# Examples:	['57(55885)']
#
#
# Category:	55891
# Count:	1
# Examples:	['63(55891)']
#
#
# Category:	55853
# Count:	1
# Examples:	['25(55853)']
#
#
# Category:	55840
# Count:	1
# Examples:	['12(55840)']
#
#
# Category:	55867
# Count:	1
# Examples:	['39(55867)']
#
#
# Category:	55854
# Count:	1
# Examples:	['26(55854)']
#
#
# Category:	55871
# Count:	1
# Examples:	['43(55871)']
#
#
# Category:	55877
# Count:	1
# Examples:	['49(55877)']
#
#
# Category:	55832
# Count:	1
# Examples:	['4(55832)']
#
#
# Category:	55829
# Count:	1
# Examples:	['1(55829)']
#
#
# Category:	55881
# Count:	1
# Examples:	['53(55881)']
#
#
# Category:	55895
# Count:	1
# Examples:	['67(55895)']
#
#
# Category:	55868
# Count:	1
# Examples:	['40(55868)']
#
#
# Category:	55894
# Count:	1
# Examples:	['66(55894)']
#
#
# Category:	55875
# Count:	1
# Examples:	['47(55875)']
#
#
# Category:	55904
# Count:	1
# Examples:	['76(55904)']
#
#
# Category:	55835
# Count:	1
# Examples:	['7(55835)']
#
#
# Category:	55873
# Count:	1
# Examples:	['45(55873)']
#
#
# Category:	55882
# Count:	1
# Examples:	['54(55882)']
#
#
# Category:	55906
# Count:	1
# Examples:	['78(55906)']
#
#
# Category:	55866
# Count:	1
# Examples:	['38(55866)']
#
#
# Category:	55892
# Count:	1
# Examples:	['64(55892)']
#
#
# Category:	55884
# Count:	1
# Examples:	['56(55884)']
#
#
# Category:	55905
# Count:	1
# Examples:	['77(55905)']
#
#
# Category:	55893
# Count:	1
# Examples:	['65(55893)']
#
#
# Category:	55874
# Count:	1
# Examples:	['46(55874)']
#
#
# Category:	55883
# Count:	1
# Examples:	['55(55883)']
#
#
# Category:	55837
# Count:	1
# Examples:	['9(55837)']
#
#
# Category:	55838
# Count:	1
# Examples:	['10(55838)']
#
#
# Category:	55856
# Count:	1
# Examples:	['28(55856)']
#
#
# Category:	6969
# Count:	10
# Examples:	['34%20Borgo%20a%20Cascia(6969)', '27%20Borgo%20a%20Cascia(6969)', '1%20Borgo%20a%20Cascia(6969)', '2%20Borgo%20a%20Cascia(6969)', '29%20Borgo%20a%20Cascia(6969)']
#
#
# Category:	55642
# Count:	7
# Examples:	['10(55642)', '7%20Artini(55642)', '35(55642)', '36%20Artini(55642)', '32(55642)']
#
#
# Category:	56386
# Count:	2
# Examples:	['13(56386)', '10(56386)']
#
#
# Category:	56408
# Count:	3
# Examples:	['17(56408)', '16(56408)', '14(56408)']
#
#
# Category:	31053
# Count:	1
# Examples:	['293(31053)']
#
#
# Category:	56382
# Count:	3
# Examples:	['16(56382)', '10(56382)', '13(56382)']
#
#
# Category:	56383
# Count:	2
# Examples:	['14(56383)', '16(56383)']
#
#
# Category:	56381
# Count:	3
# Examples:	['6(56381)', '9(56381)', '7(56381)']
#
#
# Category:	56391
# Count:	3
# Examples:	['14(56391)', '16(56391)', '18(56391)']
#
#
# Category:	56376
# Count:	2
# Examples:	['2(56376)', '5(56376)']
#
#
# Category:	56380
# Count:	3
# Examples:	['18(56380)', '3(56380)', '1(56380)']
#
#
# Category:	56377
# Count:	2
# Examples:	['6(56377)', '9(56377)']
#
#
# Category:	11
# Count:	2
# Examples:	['27(11)', '40(11)']
#
#
# Category:	653
# Count:	1
# Examples:	['61(653)']
#
#
# Category:	12407
# Count:	3
# Examples:	['66(12407)', '71(12407)', '67(12407)']
#
#
# Category:	56372
# Count:	3
# Examples:	['3(56372)', '1(56372)', '4(56372)']
#
#
# Category:	56373
# Count:	3
# Examples:	['9(56373)', '7(56373)', '46(56373)']
#
#
# Category:	31048
# Count:	1
# Examples:	['214%20Bazzecchi(31048)']
#
#
# Category:	LA%201883
# Count:	3
# Examples:	['4(LA%201883)', '8(LA%201883)', '12(LA%201883)']
#
#
# Category:	LA%201874
# Count:	3
# Examples:	['68(LA%201874)', '70(LA%201874)', '72(LA%201874)']
#
#
# Category:	De%20Giovanni%20Maddalena%2041
# Count:	83
# Examples:	['82(De%20Giovanni%20Maddalena%2041)', '7(De%20Giovanni%20Maddalena%2041)', '3(De%20Giovanni%20Maddalena%2041)', '19(De%20Giovanni%20Maddalena%2041)', '15(De%20Giovanni%20Maddalena%2041)']
#
#
# Category:	31042
# Count:	2
# Examples:	['181%20Bazzechi(31042)', '179%20Bazzechi(31042)']
#
#
# Category:	55505
# Count:	1
# Examples:	['15(55505)']
#
#
# Category:	LA%201866
# Count:	12
# Examples:	['71(LA%201866)', '73(LA%201866)', '7(LA%201866)', '3(LA%201866)', '59(LA%201866)']
#
#
# Category:	1866
# Count:	3
# Examples:	['39(1866)', '47(1866)', '45(1866)']
#
#
# Category:	LA%201880
# Count:	1
# Examples:	['4(LA%201880)']
#
#
# Category:	31032
# Count:	2
# Examples:	['142%20Bazzechi(31032)', '141%20Bazzechi(31032)']
#
#
# Category:	31039
# Count:	2
# Examples:	['167%20Bazzechi(31039)', '170%20Bazzechi(31039)']
#
#
# Category:	29297
# Count:	1
# Examples:	['17%20Bazzechi(29297)']
#
#
# Category:	31018
# Count:	2
# Examples:	['70%20Bazzechi(31018)', '73%20Bazzechi(31018)']
#
#
# Category:	31037
# Count:	1
# Examples:	['159%20Bazzechi(31037)']
#
#
# Category:	31036
# Count:	3
# Examples:	['155%20Bazzechi(31036)', '156%20Bazzechi(31036)', '158%20Bazzechi(31036)']
#
#
# Category:	31034
# Count:	3
# Examples:	['150%20Bazzechi(31034)', '148%20Bazzechi(31034)', '147%20Bazzechi(31034)']
#
#
# Category:	31071
# Count:	3
# Examples:	['12(31071)', '13(31071)', '9(31071)']
#
#
# Category:	31035
# Count:	3
# Examples:	['153%20Bazzechi(31035)', '152%20Bazzechi(31035)', '154%20Bazzechi(31035)']
#
#
# Category:	31001
# Count:	3
# Examples:	['2%20Bazzechi(31001)', '3%20Bazzechi(31001)', '1%20Bazzechi(31001)']
#
#
# Category:	31021
# Count:	1
# Examples:	['92%20Bazzechi(31021)']
#
#
# Category:	56416
# Count:	2
# Examples:	['14(56416)', '17(56416)']
#
#
# Category:	56415
# Count:	2
# Examples:	['13(56415)', '10(56415)']
#
#
# Category:	15323
# Count:	11
# Examples:	['29(15323)', '26(15323)', '23(15323)', '28(15323)', '22a(15323)']
#
#
# Category:	15326
# Count:	8
# Examples:	['57(15326)', '53(15326)', '60(15326)', '58(15326)', '59(15326)']
#
#
# Category:	15324
# Count:	11
# Examples:	['38(15324)', '31(15324)', '32(15324)', '33(15324)', '34(15324)']
#
#
# Category:	15322
# Count:	12
# Examples:	['12(15322)', '13(15322)', '14a(15322)', '14b(15322)', '15(15322)']
#
#
# Category:	29820
# Count:	2
# Examples:	['2(29820)', '1(29820)']
#
#
# Category:	56389
# Count:	3
# Examples:	['9(56389)', '6(56389)', '7(56389)']
#
#
# Category:	51872
# Count:	1
# Examples:	['a%20Artini(51872)']
#
#
# Category:	12408
# Count:	2
# Examples:	['86(12408)', '85(12408)']
#
#
# Category:	12409
# Count:	2
# Examples:	['95(12409)', '92(12409)']
#
#
# Category:	12404
# Count:	4
# Examples:	['37(12404)', '38(12404)', '39(12404)', '33(12404)']
#
#
# Category:	12406
# Count:	3
# Examples:	['60(12406)', '59(12406)', '62(12406)']
#
#
# Category:	31056
# Count:	3
# Examples:	['303(31056)', '305(31056)', '302(31056)']
#
#
# Category:	31016
# Count:	2
# Examples:	['63%20Bazzechi(31016)', '64%20Bazzechi(31016)']
#
#
# Category:	31025
# Count:	2
# Examples:	['111%20Bazzechi(31025)', '112%20Bazzechi(31025)']
#
#
# Category:	31070
# Count:	2
# Examples:	['6(31070)', '8(31070)']
#
#
# Category:	31023
# Count:	2
# Examples:	['100%20Bazzechi(31023)', '101%20Bazzechi(31023)']
#
#
# Category:	31064
# Count:	3
# Examples:	['11(31064)', '10(31064)', '9(31064)']
#
#
# Category:	31022
# Count:	3
# Examples:	['99%20Bazzechi(31022)', '98%20Bazzechi(31022)', '96%20Bazzechi(31022)']
#
#
# Category:	31027
# Count:	5
# Examples:	['121%20Bazzechi(31027)', '122%20Bazzechi(31027)', '123%20Bazzechi(31027)', '119%20Bazzechi(31027)', '118%20Bazzechi(31027)']
#
#
# Category:	31055
# Count:	2
# Examples:	['300(31055)', '301(31055)']
#
#
# Category:	31026
# Count:	2
# Examples:	['113%20Bazzechi(31026)', '115%20Bazzechi(31026)']
#
#
# Category:	31028
# Count:	1
# Examples:	['124%20Bazzechi(31028)']
#
#
# Category:	55810
# Count:	1
# Examples:	['col(55810)']
#
#
# Category:	55824
# Count:	5
# Examples:	['13(55824)', '12(55824)', '10(55824)', '18(55824)', '15(55824)']
#
#
# Category:	De%20Giovanni%20B.I.%20Transetto%20sin.%201
# Count:	152
# Examples:	['141(De%20Giovanni%20B.I.%20Transetto%20sin.%201)', '148(De%20Giovanni%20B.I.%20Transetto%20sin.%201)', '142(De%20Giovanni%20B.I.%20Transetto%20sin.%201)', '147(De%20Giovanni%20B.I.%20Transetto%20sin.%201)', '143(De%20Giovanni%20B.I.%20Transetto%20sin.%201)']
#
#
# Category:	821
# Count:	2
# Examples:	['17a(821)', '16a(821)']
#
#
# Category:	823
# Count:	4
# Examples:	['31(823)', '34(823)', '33(823)', '35(823)']
#
#
# Category:	822
# Count:	8
# Examples:	['19(822)', '26(822)', '20(822)', '28(822)', '24(822)']
#
#
# Category:	56379
# Count:	2
# Examples:	['16(56379)', '15(56379)']
#
#
# Category:	56374
# Count:	2
# Examples:	['12(56374)', '10(56374)']
#
#
# Category:	56375
# Count:	1
# Examples:	['15(56375)']
#
#
# Category:	51823
# Count:	3
# Examples:	['292(51823)', '297(51823)', '299(51823)']
#
#
# Category:	56426
# Count:	3
# Examples:	['8(56426)', '6(56426)', '7(56426)']
#
#
# Category:	9
# Count:	2
# Examples:	['col(9)', '6(9)']
#
#
# Category:	31017
# Count:	3
# Examples:	['66%20Bazzechi(31017)', '69%20Bazzechi(31017)', '68%20Bazzechi(31017)']
#
#
# Category:	32
# Count:	1
# Examples:	['34(32)']
#
#
# Category:	88
# Count:	1
# Examples:	['265(88)']
#
#
# Category:	765
# Count:	3
# Examples:	['23(765)', '20(765)', '21(765)']
#
#
# Category:	5172
# Count:	1
# Examples:	['1%20Artini(5172)']
#
#
# Category:	28939
# Count:	1
# Examples:	['3(28939)']
#
#
# Category:	7
# Count:	5
# Examples:	['col(7)', '31A(7)', '8A(7)', '14A(7)', '20A(7)']
#
#
# Category:	31002
# Count:	4
# Examples:	['7%20Bazzechi(31002)', '12%20Bazzechi(31002)', '9%20Bazzechi(31002)', '8%20Bazzechi(31002)']
#
#
# Category:	983a
# Count:	1
# Examples:	['94(983a)']
#
#
# Category:	8503
# Count:	2
# Examples:	['12(8503)', '9(8503)']
#
#
# Category:	C
# Count:	5
# Examples:	['2339(C)', '2350(C)', '2351(C)', '2340(C)', '2345(C)']
#
#
# Category:	55821
# Count:	3
# Examples:	['18(55821)', '12(55821)', '13(55821)']
#
#
# Category:	55822
# Count:	4
# Examples:	['4(55822)', '1(55822)', '9(55822)', '7(55822)']
#
#
# Category:	XXV788
# Count:	1
# Examples:	['261(XXV788)']
#
#
# Category:	56400
# Count:	1
# Examples:	['8(56400)']
#
#
# Category:	55813
# Count:	1
# Examples:	['col(55813)']
#
#
# Category:	55797
# Count:	1
# Examples:	['col(55797)']
#
#
# Category:	55806
# Count:	1
# Examples:	['col(55806)']
#
#
# Category:	12
# Count:	7
# Examples:	['col(12)', '17A(12)', '22A(12)', '26A(12)', '35A(12)']
#
#
# Category:	1875
# Count:	1
# Examples:	['73(1875)']
#
#
# Category:	55803a
# Count:	1
# Examples:	['col(55803a)']
#
#
# Category:	55812
# Count:	1
# Examples:	['col(55812)']
#
#
# Category:	56384
# Count:	2
# Examples:	['4(56384)', '3(56384)']
#
#
# Category:	56526
# Count:	1
# Examples:	['A(56526)']
#
#
# Category:	56525
# Count:	1
# Examples:	['A(56525)']
#
#
# Category:	27905
# Count:	2
# Examples:	['18(27905)', '16(27905)']
#
#
# Category:	56421
# Count:	2
# Examples:	['4(56421)', '3(56421)']
#
#
# Category:	56437
# Count:	2
# Examples:	['4(56437)', '3(56437)']
#
#
# Category:	56420
# Count:	3
# Examples:	['17(56420)', '16(56420)', '14(56420)']
#
#
# Category:	56438
# Count:	3
# Examples:	['9(56438)', '6(56438)', '7(56438)']
#
#
# Category:	56428
# Count:	3
# Examples:	['16(56428)', '15(56428)', '18(56428)']
#
#
# Category:	56418
# Count:	2
# Examples:	['7(56418)', '6(56418)']
#
#
# Category:	56436
# Count:	2
# Examples:	['18(56436)', '16(56436)']
#
#
# Category:	56422
# Count:	2
# Examples:	['6(56422)', '9(56422)']
#
#
# Category:	56432
# Count:	3
# Examples:	['14(56432)', '18(56432)', '16(56432)']
#
#
# Category:	656
# Count:	16
# Examples:	['22(656)', '19(656)', '16(656)', '21(656)', '24(656)']
#
#
# Category:	Helbig%20PO
# Count:	2
# Examples:	['42(Helbig%20PO)', '18(Helbig%20PO)']
#
#
# Category:	56433
# Count:	2
# Examples:	['4(56433)', '3(56433)']
#
#
# Category:	56434
# Count:	1
# Examples:	['6(56434)']
#
#
# Category:	55653
# Count:	2
# Examples:	['33(55653)', '35(55653)']
#
#
# Category:	63502%3F%20
# Count:	1
# Examples:	['%2063503%3F(63502%3F%20)']
#
#
# Category:	31019
# Count:	4
# Examples:	['76%20Bazzechi(31019)', '74%20Bazzechi(31019)', '75%20Bazzechi(31019)', '77%20Bazzechi(31019)']
#
#
# Category:	De%20Giovanni%207
# Count:	12
# Examples:	['249(De%20Giovanni%207)', '256(De%20Giovanni%207)', '248(De%20Giovanni%207)', '252b(De%20Giovanni%207)', '347(De%20Giovanni%207)']
#
#
# Category:	De%20Giovanni%208
# Count:	2
# Examples:	['345(De%20Giovanni%208)', '348(De%20Giovanni%208)']
#
#
# Category:	852
# Count:	2
# Examples:	['24%20%2827A%29(852)', '24%20%2828A%29(852)']
#
#
# Category:	31009
# Count:	2
# Examples:	['39%20Bazzechi(31009)', '38%20Bazzechi(31009)']
#
#
# Category:	13
# Count:	6
# Examples:	['23A(13)', '36A(13)', '18A(13)', '31A(13)', '3A(13)']
#
#
# Category:	74
# Count:	1
# Examples:	['3(74)']
#
#
# Category:	40
# Count:	1
# Examples:	['85(40)']
#
#
# Category:	12405
# Count:	6
# Examples:	['41(12405)', '42(12405)', '51(12405)', '46(12405)', '47(12405)']
#
#
# Category:	51869
# Count:	1
# Examples:	['a%20Artini(51869)']
#
#
# Category:	Artini%204721
# Count:	1
# Examples:	['42(Artini%204721)']
#
#
# Category:	56396
# Count:	2
# Examples:	['4(56396)', '3(56396)']
#
#
# Category:	56395
# Count:	3
# Examples:	['16(56395)', '18(56395)', '15(56395)']
#
#
# Category:	56402
# Count:	3
# Examples:	['6(56402)', '7(56402)', '9(56402)']
#
#
# Category:	56399
# Count:	3
# Examples:	['17(56399)', '14(56399)', '16(56399)']
#
#
# Category:	56401
# Count:	2
# Examples:	['1(56401)', '4(56401)']
#
#
# Category:	56398
# Count:	1
# Examples:	['13(56398)']
#
#
# Category:	15
# Count:	3
# Examples:	['2(15)', '6(15)', '10(15)']
#
#
# Category:	56530
# Count:	1
# Examples:	['A(56530)']
#
#
# Category:	2554%20
# Count:	1
# Examples:	['%206106(2554%20)']
#
#
# Category:	17
# Count:	3
# Examples:	['33A(17)', '15A(17)', '17A(17)']
#
#
# Category:	56405
# Count:	3
# Examples:	['3(56405)', '4(56405)', '1(56405)']
#
#
# Category:	56387
# Count:	3
# Examples:	['17(56387)', '16(56387)', '14(56387)']
#
#
# Category:	B%2030.451
# Count:	2
# Examples:	['11(B%2030.451)', '4(B%2030.451)']
#
#
# Category:	56393
# Count:	3
# Examples:	['7(56393)', '9(56393)', '6(56393)']
#
#
# Category:	56388
# Count:	3
# Examples:	['3(56388)', '1(56388)', '4(56388)']
#
#
# Category:	15214
# Count:	10
# Examples:	['10(15214)', '2(15214)', '1(15214)', '17(15214)', '11(15214)']
#
#
# Category:	15211
# Count:	5
# Examples:	['7(15211)', '4(15211)', '1(15211)', '2(15211)', '5(15211)']
#
#
# Category:	5214
# Count:	1
# Examples:	['13(5214)']
#
#
# Category:	55937
# Count:	2
# Examples:	['A(55937)', 'B(55937)']
#
#
# Category:	55938
# Count:	1
# Examples:	['A(55938)']
#
#
# Category:	56521
# Count:	2
# Examples:	['B(56521)', 'A(56521)']
#
#
# Category:	56522
# Count:	2
# Examples:	['A(56522)', 'B(56522)']
#
#
# Category:	774
# Count:	3
# Examples:	['54%20Artini(774)', '55%20Artini(774)', '53%20Artini(774)']
#
#
# Category:	56404
# Count:	1
# Examples:	['17(56404)']
#
#
# Category:	56378
# Count:	2
# Examples:	['14(56378)', '10(56378)']
#
#
# Category:	56406
# Count:	3
# Examples:	['5(56406)', '7(56406)', '8(56406)']
#
#
# Category:	56392
# Count:	3
# Examples:	['4(56392)', '3(56392)', '1(56392)']
#
#
# Category:	56385
# Count:	1
# Examples:	['9(56385)']
#
#
# Category:	FI.%2045.884
# Count:	1
# Examples:	['1998(FI.%2045.884)']
#
#
# Category:	31044
# Count:	1
# Examples:	['193%20Bazzechi(31044)']
#
#
# Category:	2128%20
# Count:	1
# Examples:	['%201122(2128%20)']
#
#
# Category:	31003
# Count:	3
# Examples:	['13%20Bazzechi(31003)', '16%20Bazzechi(31003)', '15%20Bazzechi(31003)']
#
#
# Category:	55908
# Count:	1
# Examples:	['80(55908)']
#
#
# Category:	31045
# Count:	1
# Examples:	['204%20Bazzechi(31045)']
#
#
# Category:	31007
# Count:	1
# Examples:	['30%20Bazzechi(31007)']
#
#
# Category:	55797a
# Count:	1
# Examples:	['col(55797a)']
#
#
# Category:	55797b
# Count:	1
# Examples:	['col(55797b)']
#
#
# Category:	31040
# Count:	1
# Examples:	['173%20Bazzechi(31040)']
#
#
# Category:	55907
# Count:	1
# Examples:	['79(55907)']
#
#
# Category:	15321
# Count:	9
# Examples:	['9(15321)', '4(15321)', '5(15321)', '6(15321)', '2(15321)']
#
#
# Category:	27894
# Count:	2
# Examples:	['1(27894)', '3(27894)']
#
#
# Category:	655
# Count:	8
# Examples:	['3(655)', '7(655)', '8(655)', '5(655)', '6(655)']
#
#
# Category:	27892
# Count:	3
# Examples:	['10(27892)', '12(27892)', '13(27892)']
#
#
# Category:	27900
# Count:	1
# Examples:	['1(27900)']
#
#
# Category:	297904
# Count:	1
# Examples:	['11(297904)']
#
#
# Category:	27903
# Count:	2
# Examples:	['7(27903)', '5(27903)']
#
#
# Category:	27896
# Count:	2
# Examples:	['12(27896)', '10(27896)']
#
#
# Category:	27902
# Count:	1
# Examples:	['4(27902)']
#
#
# Category:	27891
# Count:	1
# Examples:	['9(27891)']
#
#
# Category:	27895
# Count:	1
# Examples:	['9(27895)']
#
#
# Category:	27904
# Count:	2
# Examples:	['10(27904)', '13(27904)']
#
#
# Category:	55640
# Count:	2
# Examples:	['26(55640)', '27(55640)']
#
#
# Category:	55639
# Count:	9
# Examples:	['23(55639)', '12(55639)', '7(55639)', '10(55639)', '5(55639)']
#
#
# Category:	13141
# Count:	2
# Examples:	['24%20Artini(13141)', '23%20Artini(13141)']
#
#
# Category:	13140
# Count:	3
# Examples:	['10%20Artini(13140)', '8%20Artini(13140)', '5%20Artini(13140)']
#
#
# Category:	27510
# Count:	1
# Examples:	['15(27510)']
#
#
# Category:	56520
# Count:	2
# Examples:	['A(56520)', 'B(56520)']
#
#
# Category:	56523
# Count:	1
# Examples:	['A(56523)']
#
#
# Category:	31014
# Count:	1
# Examples:	['56%20Bazzechi(31014)']
#
#
# Category:	31031
# Count:	1
# Examples:	['139%20Bazzechi(31031)']
#
#
# Category:	28653
# Count:	1
# Examples:	['15%20Artini(28653)']
#
#
# Category:	4774
# Count:	1
# Examples:	['114%20Artini(4774)']
#
#
# Category:	56403
# Count:	1
# Examples:	['10(56403)']
#
#
# Category:	group
# Count:	5
# Examples:	['2D203EE2-849C-39DA-86F8-87EF1627E61D(group)', '389962C9-DEC5-30AB-A8D0-4517E82C3996(group)', '64F60790-6BE7-398A-82D7-5DBC1E979662(group)', '3C2F8B8C-8C43-338B-A5A0-327AE84C3F65(group)', '65F7B8E1-7E93-3C2A-8784-3D99E82C08A5(group)']

# %%
key_length = 0
for element in data:
    key_length += len(data[element].keys())

# %% [markdown]
# #### Dumping the data

# %%
with open("data/entity_dump_cleaned_and_restructured.json", "w", encoding="utf8") as f:
    json.dump(restructured_data, f, indent=4)
