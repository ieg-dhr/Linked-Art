# %%
import networkx as nx
import json
import matplotlib.pyplot as plt
import operator
from collections import Counter
from networkx.algorithms import bipartite

# %%
with open("data/entity_dump_cleaned_and_restructured.json", encoding = 'cp1252') as f:
    data = json.load(f)

# %% [markdown]
# ### Auxiliary functions

# %%
def exchange_id_with_value(id):
    value = data[id]
    for index in range(len(data[id])):
        for index_2 in range(len(data[id][index])):
            if type(data[id][index][index_2]) == dict:
                label = data[id][index][index_2]["Label"]
                break


    return label

# %% [markdown]
# ### Dictionaries of classes

# %%
work_dict = {}
for key in list(data.keys()):
    if key.__contains__("work"):
        work_dict[key] = data[key]

# %%
photo_dict = {}
for key in list(data.keys()):
    if key.__contains__("photo"):
        photo_dict[key] = data[key]

# %% [markdown]
# ### Finding relations

# %% [markdown]
# #### First artworks and artists

# %%
works_and_artists = {}
for work in list(work_dict.keys()):
    
    work_as_key = None
    artist_id = "No Artist"
    profession_id = None
    
    
    for attribute in work_dict[work]:
        for index in range(len(attribute)):
            if type(attribute[index]) == list and attribute[index][0] == "PC14_carried_out_by(cidoc-crm)":
                work_as_key = work.split("(")[0]
                artist_id = attribute[index][1].split("(")[0]
            elif type(attribute[index]) == list and attribute[index][1] == "PC14_carried_out_by(cidoc-crm)":
                work_as_key = work.split("(")[0]
                artist_id = attribute[index][0].split("(")[0]

            if type(attribute[index]) == list and attribute[index][0] == "P14.1_in_the_role_of(cidoc-crm)":
                profession_id = exchange_id_with_value(attribute[index][1])
            elif type(attribute[index]) == list and attribute[index][0] == "P14.1_in_the_role_of(cidoc-crm)":
                profession_id = exchange_id_with_value(attribute[index][0])

    if work_as_key != None:
        works_and_artists[work_as_key] = (artist_id, profession_id)
    
      
    if work_as_key == None:
        work_as_key = work.split("(")[0]
        works_and_artists[work_as_key] = ["No Artist", None]

# %%
# example of the dictionary structure
count = 0

for idx, (k, v) in enumerate(works_and_artists.items()):
    if v[0] == 'No Artist':
        continue
    else:
        print((k, v))
        count += 1
        
    if count == 5:
        break
# Out:
# ('07602583%2CT%2C001', ('07600210', 'Bildhauer'))
# ('07602583%2CT%2C005', ('00086500', 'Bildhauer'))
# ('07602583%2CT%2C004', ('00086500', 'Bildhauer'))
# ('07602583%2CT%2C002', ('00086500', 'Bildhauer'))
# ('07602583%2CT%2C003', ('00086500', 'Bildhauer'))

# %%
G = nx.Graph()

for idx, (k, v) in enumerate(works_and_artists.items()):
    if v[0] == 'No Artist':
        continue
    else:
        G.add_node(k, ent='artwork')
        if v[1] == None:
            G.add_node(v[0], ent='artist', profession='NA')
        else:
            G.add_node(v[0], ent='artist', profession=v[1])
        G.add_edge(k,v[0],weight=1)

# %%
artworks = {n for n, d in G.nodes(data=True) if d["ent"] == 'artwork'}
artists = set(G) - artworks

# %%
print(len(artworks))
print(len(artists))
print(len(G.edges()))
# Out:
# 52381
# 5485
# 53636

# %% [markdown]
# #### Second, artworks and photos

# %%
# all the photos that have a relation with an artwork
photos_with_works = {}
for counter, photo in enumerate(photo_dict):
    for attribute in photo_dict[photo]:
        for index in range(len(attribute)):
            if type(attribute[index]) == list and "P128_carries(cidoc-crm)" in attribute[index]:
                photos_with_works[photo] = photo_dict[photo]

# %%
# example of the dictionary structure
for idx, (k, v) in enumerate(photos_with_works.items()):
    if idx == 5: 
        break
    else:
        print((k, v))
# Out:
# ('fln0419237z_p(photo)', [[['61(746)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': '746/61'}, ['P2_has_type(cidoc-crm)', '300127173(aat)']], [['C005A1DD-D117-3CA1-96E0-86DD3C5F6718(acquisition)', 'E8_Acquisition(cidoc-crm)'], ['P4_has_time-span(cidoc-crm)', '921EF3FA-2031-329D-91F1-3CE104C2B18D(timespan)']], [['fln0419237z_p(photo)', 'Namedgraph(custom)'], ['has_provider(custom)', 'KHI(source)']], [['fln0419237z_p(photo)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': 'fln0419237z_p'}, ['P108i_was_produced_by(cidoc-crm)', 'production(fln0419237z_p)'], ['P128_carries(cidoc-crm)', 'visual_item(07650134)'], ['P129i_is_subject_of(cidoc-crm)', 'default.jpg(0)'], ['P1_is_identified_by(cidoc-crm)', 'E4EBEBAD-9A32-30C2-8185-7B091C31F076(identifier)'], ['P24i_changed_ownership_through(cidoc-crm)', 'C005A1DD-D117-3CA1-96E0-86DD3C5F6718(acquisition)'], ['P2_has_type(cidoc-crm)', '300127104(aat)'], ['P43_has_dimension(cidoc-crm)', 'ACAD540B-9BCA-31FF-89DD-578CCC8BB592(-)'], ['P50_has_current_keeper(cidoc-crm)', '07BA34AD-F580-3D38-ADBE-F9BF8E322D20(actor)'], ['P67i_is_referred_to_by(cidoc-crm)', 'fln0419237z_p(photo)'], ['has_provider(custom)', 'KHI(source)']], [['921EF3FA-2031-329D-91F1-3CE104C2B18D(timespan)', 'E52_Time-Span(cidoc-crm)'], {'Label': '1984.07.12'}], [['ACAD540B-9BCA-31FF-89DD-578CCC8BB592(-)', 'E54_Dimension(cidoc-crm)'], ['P2_has_type(cidoc-crm)', '300127013(aat)'], {'Label': 'monochrom'}], [['timespan(production)', 'E52_Time-Span(cidoc-crm)'], {'Label': '1984.07'}], [['FBC07026-BCAE-3B6A-BFA5-CEFEF26F5764(appellation)', 'E41_Appellation(cidoc-crm)'], {'Label': 'fln0419237z_p'}, ['P2_has_type(cidoc-crm)', '300417193(aat)']], [['info.json(thumbnails%2Ffln0419237z_p.jpg)', 'E73_Information_Object(cidoc-crm)']], [['default.jpg(0)', 'D1_Digital_Object(CRMdig.rdfs)'], ['P129i_is_subject_of(cidoc-crm)', 'info.json(thumbnails%2Ffln0419237z_p.jpg)'], ['P2_has_type(cidoc-crm)', 'image(api)']], [['300046300(aat)', 'P2_has_type(cidoc-crm)']], [['E4EBEBAD-9A32-30C2-8185-7B091C31F076(identifier)', 'E42_Identifier(cidoc-crm)'], {'Label': '419237'}, ['P2_has_type(cidoc-crm)', '300404621(aat)']], [['production(fln0419237z_p)', 'E12_Production(cidoc-crm)'], ['P125_used_object_of_type(cidoc-crm)', '02D7339E-C31F-3ED7-A56E-C6518A2F9B2D(type)'], ['P4_has_time-span(cidoc-crm)', 'timespan(production)']], [['53F3EC53-529E-3591-B568-E957F0F8CCAB(-)', 'E54_Dimension(cidoc-crm)'], {'Label': '6x6'}], [['visual_item(07650134)', 'E36_Visual_Item(cidoc-crm)'], ['P128i_is_carried_by(cidoc-crm)', '61(746)']], [['image(api)', 'E55_Type(cidoc-crm)'], {'Label': 'iiif.io/api/image'}], [['65F17ECC-8E9A-36FB-A48C-7F14D0A1AC46(credit_line_info)', 'E73_Information_Object(cidoc-crm)'], {'Label': 'KunsthistorischesInstitutinFlorenz,Max-Planck-Institut'}, ['P2_has_type(cidoc-crm)', '300435418(aat)']]])
# ('fln0320499z_p(photo)', [[['fln0320499z_p(photo)', 'Namedgraph(custom)'], ['has_provider(custom)', 'KHI(source)']], [['visual_item(07602583%2CT%2C009)', 'E36_Visual_Item(cidoc-crm)'], ['P128i_is_carried_by(cidoc-crm)', '1327%20Artini(negative)']], [['0907C45D-91DA-3BB6-93A2-CDE32CF017C7(identifier)', 'E42_Identifier(cidoc-crm)'], {'Label': '320499'}, ['P2_has_type(cidoc-crm)', '300404621(aat)']], [['fln0320499z_p(photo)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': 'fln0320499z_p'}, ['P108i_was_produced_by(cidoc-crm)', 'production(fln0320499z_p)'], ['P128_carries(cidoc-crm)', 'visual_item(07602583%2CT%2C009)'], ['P129i_is_subject_of(cidoc-crm)', 'default.jpg(0)'], ['P1_is_identified_by(cidoc-crm)', '0907C45D-91DA-3BB6-93A2-CDE32CF017C7(identifier)'], ['P24i_changed_ownership_through(cidoc-crm)', 'C5415870-48D6-312F-9EA9-4600283B13B6(acquisition)'], ['P2_has_type(cidoc-crm)', '300046300(aat)'], ['P43_has_dimension(cidoc-crm)', '8A7CEEE2-73AD-3E78-BCB8-40F6A1243CC9(-)'], ['P50_has_current_keeper(cidoc-crm)', '07BA34AD-F580-3D38-ADBE-F9BF8E322D20(actor)'], ['P67i_is_referred_to_by(cidoc-crm)', 'fln0320499z_p(photo)'], ['has_provider(custom)', 'KHI(source)']], [['C5415870-48D6-312F-9EA9-4600283B13B6(acquisition)', 'E8_Acquisition(cidoc-crm)'], {'Label': 'FormerLocation:Lisner,Margrit-Acquisition:Geschenk-1976.06.10-'}, ['P22_transferred_title_from(cidoc-crm)', '5807448F-706A-3588-8341-00C46C92104E(actor)'], ['P2_has_type(cidoc-crm)', 'F661BEFD-A72B-3534-9F6B-199847830E81(type)'], ['P4_has_time-span(cidoc-crm)', 'C57C7C81-F575-3F75-A8B7-99B4EF896174(timespan)']], [['info.json(thumbnails%2Ffln0320499z_p.jpg)', 'E73_Information_Object(cidoc-crm)']], [['8A7CEEE2-73AD-3E78-BCB8-40F6A1243CC9(-)', 'E54_Dimension(cidoc-crm)'], {'Label': '13x18'}], [['ACAD540B-9BCA-31FF-89DD-578CCC8BB592(-)', 'E54_Dimension(cidoc-crm)'], ['P2_has_type(cidoc-crm)', '300127013(aat)'], {'Label': 'monochrom'}], [['1327%20Artini(negative)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': '1327Artini'}, ['P2_has_type(cidoc-crm)', '300127173(aat)']], [['default.jpg(0)', 'D1_Digital_Object(CRMdig.rdfs)'], ['P129i_is_subject_of(cidoc-crm)', 'info.json(thumbnails%2Ffln0320499z_p.jpg)'], ['P2_has_type(cidoc-crm)', 'image(api)']], [['300046300(aat)', 'P2_has_type(cidoc-crm)']], [['production(fln0320499z_p)', 'E12_Production(cidoc-crm)'], ['P125_used_object_of_type(cidoc-crm)', '194C1FAF-9185-3CF7-AA11-91438B5B5366(type)'], ['P14_carried_out_by(cidoc-crm)', '0832F1B2-0FF5-31AD-AE3B-8D326DE3528D(actor)']], [['C57C7C81-F575-3F75-A8B7-99B4EF896174(timespan)', 'E52_Time-Span(cidoc-crm)'], {'Label': '1976.06.10'}], [['3813A092-BAC2-33B2-960B-BE166F3211C5(appellation)', 'E41_Appellation(cidoc-crm)'], {'Label': 'fln0320499z_p'}, ['P2_has_type(cidoc-crm)', '300417193(aat)']], [['65F17ECC-8E9A-36FB-A48C-7F14D0A1AC46(credit_line_info)', 'E73_Information_Object(cidoc-crm)'], {'Label': 'KunsthistorischesInstitutinFlorenz,Max-Planck-Institut'}, ['P2_has_type(cidoc-crm)', '300435418(aat)']], [['image(api)', 'E55_Type(cidoc-crm)'], {'Label': 'iiif.io/api/image'}]])
# ('fln0609885y_p(photo)', [[['C621844D-9008-3869-8831-2FE371E2521C(acquisition)', 'E8_Acquisition(cidoc-crm)'], ['P2_has_type(cidoc-crm)', 'B538ECE6-5D09-354E-8444-10C191F65D21(type)'], ['P4_has_time-span(cidoc-crm)', 'C9DBBBFC-1B40-3D08-A5E1-5F1B003D9337(timespan)']], [['A64C07BA-4E9A-36E0-BAB1-F9EE665C3DDF(-)', 'E54_Dimension(cidoc-crm)'], {'Label': '18x24'}], [['production(fln0609885y_p)', 'E12_Production(cidoc-crm)'], ['P125_used_object_of_type(cidoc-crm)', '6F7BEC87-39C3-317D-B153-13FB06249C40(type)']], [['default.jpg(0)', 'D1_Digital_Object(CRMdig.rdfs)'], ['P129i_is_subject_of(cidoc-crm)', 'info.json(thumbnails%2Ffln0609885y_p.jpg)'], ['P2_has_type(cidoc-crm)', 'image(api)']], [['42F03E6C-41E4-3614-8410-A7BD14AE1E34(appellation)', 'E41_Appellation(cidoc-crm)'], {'Label': 'fln0609885y_p'}, ['P2_has_type(cidoc-crm)', '300417193(aat)']], [['fln0609885y_p(photo)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': 'fln0609885y_p'}, ['P108i_was_produced_by(cidoc-crm)', 'production(fln0609885y_p)'], ['P128_carries(cidoc-crm)', 'visual_item(07602589)'], ['P129i_is_subject_of(cidoc-crm)', 'default.jpg(0)'], ['P1_is_identified_by(cidoc-crm)', '42F03E6C-41E4-3614-8410-A7BD14AE1E34(appellation)'], ['P24i_changed_ownership_through(cidoc-crm)', 'C621844D-9008-3869-8831-2FE371E2521C(acquisition)'], ['P2_has_type(cidoc-crm)', '300127104(aat)'], ['P43_has_dimension(cidoc-crm)', 'A64C07BA-4E9A-36E0-BAB1-F9EE665C3DDF(-)'], ['P50_has_current_keeper(cidoc-crm)', '07BA34AD-F580-3D38-ADBE-F9BF8E322D20(actor)'], ['P67i_is_referred_to_by(cidoc-crm)', '65F17ECC-8E9A-36FB-A48C-7F14D0A1AC46(credit_line_info)'], ['has_provider(custom)', 'KHI(source)']], [['37(55865)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': '55865/37'}, ['P2_has_type(cidoc-crm)', '300127173(aat)']], [['visual_item(07602589)', 'E36_Visual_Item(cidoc-crm)'], ['P128i_is_carried_by(cidoc-crm)', '37(55865)']], [['fln0609885y_p(photo)', 'Namedgraph(custom)'], ['has_provider(custom)', 'KHI(source)']], [['info.json(thumbnails%2Ffln0609885y_p.jpg)', 'E73_Information_Object(cidoc-crm)']], [['65F17ECC-8E9A-36FB-A48C-7F14D0A1AC46(credit_line_info)', 'E73_Information_Object(cidoc-crm)'], {'Label': 'KunsthistorischesInstitutinFlorenz,Max-Planck-Institut'}, ['P2_has_type(cidoc-crm)', '300435418(aat)']], [['ACAD540B-9BCA-31FF-89DD-578CCC8BB592(-)', 'E54_Dimension(cidoc-crm)'], ['P2_has_type(cidoc-crm)', '300127013(aat)'], {'Label': 'monochrom'}], [['300046300(aat)', 'P2_has_type(cidoc-crm)']], [['5D606EF6-166C-319B-9877-387371618FC6(identifier)', 'E42_Identifier(cidoc-crm)'], {'Label': '609885'}, ['P2_has_type(cidoc-crm)', '300404621(aat)']], [['C9DBBBFC-1B40-3D08-A5E1-5F1B003D9337(timespan)', 'E52_Time-Span(cidoc-crm)'], {'Label': '2015.10.13'}], [['image(api)', 'E55_Type(cidoc-crm)'], {'Label': 'iiif.io/api/image'}]])
# ('fln0320501z_p(photo)', [[['53F3EC53-529E-3591-B568-E957F0F8CCAB(-)', 'E54_Dimension(cidoc-crm)'], {'Label': '6x6'}], [['visual_item(07602583%2CT%2C009)', 'E36_Visual_Item(cidoc-crm)'], ['P128i_is_carried_by(cidoc-crm)', '1330%20Artini(negative)']], [['production(fln0320501z_p)', 'E12_Production(cidoc-crm)'], ['P125_used_object_of_type(cidoc-crm)', '194C1FAF-9185-3CF7-AA11-91438B5B5366(type)'], ['P14_carried_out_by(cidoc-crm)', '0832F1B2-0FF5-31AD-AE3B-8D326DE3528D(actor)']], [['fln0320501z_p(photo)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': 'fln0320501z_p'}, ['P108i_was_produced_by(cidoc-crm)', 'production(fln0320501z_p)'], ['P128_carries(cidoc-crm)', 'visual_item(07602583%2CT%2C009)'], ['P129i_is_subject_of(cidoc-crm)', 'default.jpg(0)'], ['P1_is_identified_by(cidoc-crm)', '7D78206E-0745-3B16-87E7-F83739256C99(appellation)'], ['P24i_changed_ownership_through(cidoc-crm)', 'C5415870-48D6-312F-9EA9-4600283B13B6(acquisition)'], ['P2_has_type(cidoc-crm)', '300046300(aat)'], ['P43_has_dimension(cidoc-crm)', 'ACAD540B-9BCA-31FF-89DD-578CCC8BB592(-)'], ['P50_has_current_keeper(cidoc-crm)', '07BA34AD-F580-3D38-ADBE-F9BF8E322D20(actor)'], ['P67i_is_referred_to_by(cidoc-crm)', 'fln0320501z_p(photo)'], ['has_provider(custom)', 'KHI(source)']], [['7D78206E-0745-3B16-87E7-F83739256C99(appellation)', 'E41_Appellation(cidoc-crm)'], {'Label': 'fln0320501z_p'}, ['P2_has_type(cidoc-crm)', '300417193(aat)']], [['default.jpg(0)', 'D1_Digital_Object(CRMdig.rdfs)'], ['P129i_is_subject_of(cidoc-crm)', 'info.json(thumbnails%2Ffln0320501z_p.jpg)'], ['P2_has_type(cidoc-crm)', 'image(api)']], [['65F17ECC-8E9A-36FB-A48C-7F14D0A1AC46(credit_line_info)', 'E73_Information_Object(cidoc-crm)'], {'Label': 'KunsthistorischesInstitutinFlorenz,Max-Planck-Institut'}, ['P2_has_type(cidoc-crm)', '300435418(aat)']], [['fln0320501z_p(photo)', 'Namedgraph(custom)'], ['has_provider(custom)', 'KHI(source)']], [['E3606257-1DB5-323E-B17E-546B7DD14E9D(identifier)', 'E42_Identifier(cidoc-crm)'], {'Label': '320501'}, ['P2_has_type(cidoc-crm)', '300404621(aat)']], [['ACAD540B-9BCA-31FF-89DD-578CCC8BB592(-)', 'E54_Dimension(cidoc-crm)'], ['P2_has_type(cidoc-crm)', '300127013(aat)'], {'Label': 'monochrom'}], [['info.json(thumbnails%2Ffln0320501z_p.jpg)', 'E73_Information_Object(cidoc-crm)']], [['300046300(aat)', 'P2_has_type(cidoc-crm)']], [['1330%20Artini(negative)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': '1330Artini'}, ['P2_has_type(cidoc-crm)', '300127173(aat)']], [['C57C7C81-F575-3F75-A8B7-99B4EF896174(timespan)', 'E52_Time-Span(cidoc-crm)'], {'Label': '1976.06.10'}], [['image(api)', 'E55_Type(cidoc-crm)'], {'Label': 'iiif.io/api/image'}], [['C5415870-48D6-312F-9EA9-4600283B13B6(acquisition)', 'E8_Acquisition(cidoc-crm)'], {'Label': 'FormerLocation:Lisner,Margrit-Acquisition:Geschenk-1976.06.10-'}, ['P22_transferred_title_from(cidoc-crm)', '5807448F-706A-3588-8341-00C46C92104E(actor)'], ['P2_has_type(cidoc-crm)', 'F661BEFD-A72B-3534-9F6B-199847830E81(type)'], ['P4_has_time-span(cidoc-crm)', 'C57C7C81-F575-3F75-A8B7-99B4EF896174(timespan)']]])
# ('fln0588724z_p(photo)', [[['35.734(negative)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': '35.734'}, ['P2_has_type(cidoc-crm)', '300127173(aat)']], [['fln0588724z_p(photo)', 'Namedgraph(custom)'], ['has_provider(custom)', 'KHI(source)']], [['65F17ECC-8E9A-36FB-A48C-7F14D0A1AC46(credit_line_info)', 'E73_Information_Object(cidoc-crm)'], {'Label': 'KunsthistorischesInstitutinFlorenz,Max-Planck-Institut'}, ['P2_has_type(cidoc-crm)', '300435418(aat)']], [['production(fln0588724z_p)', 'E12_Production(cidoc-crm)'], ['P125_used_object_of_type(cidoc-crm)', '02D7339E-C31F-3ED7-A56E-C6518A2F9B2D(type)']], [['D07B9B2B-87CB-3889-A60E-28A66BB15D1C(appellation)', 'E41_Appellation(cidoc-crm)'], {'Label': 'fln0588724z_p'}, ['P2_has_type(cidoc-crm)', '300417193(aat)']], [['default.jpg(0)', 'D1_Digital_Object(CRMdig.rdfs)'], ['P129i_is_subject_of(cidoc-crm)', 'info.json(thumbnails%2Ffln0588724z_p.jpg)'], ['P2_has_type(cidoc-crm)', 'image(api)']], [['fln0588724z_p(photo)', 'E22_Man-Made_Object(cidoc-crm)'], {'Label': 'fln0588724z_p'}, ['P108i_was_produced_by(cidoc-crm)', 'production(fln0588724z_p)'], ['P128_carries(cidoc-crm)', 'visual_item(07650138)'], ['P129i_is_subject_of(cidoc-crm)', 'default.jpg(0)'], ['P1_is_identified_by(cidoc-crm)', 'D07B9B2B-87CB-3889-A60E-28A66BB15D1C(appellation)'], ['P24i_changed_ownership_through(cidoc-crm)', '62FC5FDD-8D05-3A02-855A-FA6D043753CB(acquisition)'], ['P2_has_type(cidoc-crm)', '300046300(aat)'], ['P43_has_dimension(cidoc-crm)', 'ACAD540B-9BCA-31FF-89DD-578CCC8BB592(-)'], ['P50_has_current_keeper(cidoc-crm)', '07BA34AD-F580-3D38-ADBE-F9BF8E322D20(actor)'], ['P67i_is_referred_to_by(cidoc-crm)', 'fln0588724z_p(photo)'], ['has_provider(custom)', 'KHI(source)']], [['info.json(thumbnails%2Ffln0588724z_p.jpg)', 'E73_Information_Object(cidoc-crm)']], [['62FC5FDD-8D05-3A02-855A-FA6D043753CB(acquisition)', 'E8_Acquisition(cidoc-crm)'], ['P4_has_time-span(cidoc-crm)', '9A48B05E-395A-31BD-82F4-00BE16880A92(timespan)']], [['300046300(aat)', 'P2_has_type(cidoc-crm)']], [['3DA91BCF-3DF0-383D-B15D-5069C0A7E417(identifier)', 'E42_Identifier(cidoc-crm)'], {'Label': '588724'}, ['P2_has_type(cidoc-crm)', '300404621(aat)']], [['9A48B05E-395A-31BD-82F4-00BE16880A92(timespan)', 'E52_Time-Span(cidoc-crm)'], {'Label': '2009.01.28'}], [['visual_item(07650138)', 'E36_Visual_Item(cidoc-crm)'], ['P128i_is_carried_by(cidoc-crm)', '35.734(negative)']], [['ACAD540B-9BCA-31FF-89DD-578CCC8BB592(-)', 'E54_Dimension(cidoc-crm)'], ['P2_has_type(cidoc-crm)', '300127013(aat)'], {'Label': 'monochrom'}], [['image(api)', 'E55_Type(cidoc-crm)'], {'Label': 'iiif.io/api/image'}]])

# %%
print(len(photos_with_works))
# Out:
# 33028

# %%
photographer_dict = {}

for counter, photo in enumerate(photos_with_works):
    
    photographer = None
    
    for attribute in photo_dict[photo]:
        for index in range(len(attribute)):
            if type(attribute[index]) == list and "P128_carries(cidoc-crm)" in attribute[index]:
                work_on_photo = [ element.split("(")[1].replace(")", "") for element in attribute[index] if element.__contains__("visual_item")][0]
            if type(attribute[index]) == list and "P14_carried_out_by(cidoc-crm)" in attribute[index]:
                photographer = exchange_id_with_value([element for element in attribute[index] if element.__contains__("actor")][0])
    
    if photographer == None:
        continue
    else:
        if photographer not in photographer_dict:
            photographer_dict[photographer] = [work_on_photo]
        else:
            photographer_dict[photographer].append(work_on_photo)

# %%
print(len(photographer_dict))
# Out:
# 68

# %%
# example of the dictionary structure
print(photographer_dict['Artini,Luigi'])
# Out:
# ['07602583%2CT%2C009', '07602583%2CT%2C009', '07520168', '07580639', '07580639', '07520176', '07932658', '07580638', '07580638', '07602583', '07520167', '07580639', '07520169%2CT%2C007', '07580639', '07932656', '07520175', '07520169%2CT%2C002', '07580638', '07520178', '07580639', '07580639', '07580638', '07520169%2CT%2C004', '07602583%2CT%2C009', '07520169%2CT%2C007', '07602583%2CT%2C009', '07602583%2CT%2C007', '07580638', '07932656', '07580639', '07520169%2CT%2C003', '07520178', '07580639', '07580638', '07580638', '07520169%2CT%2C005', '07520178', '07580639', '07580638', '07602583%2CT%2C007', '07932656', '07580639', '07520169%2CT%2C001', '07580638', '07580638', '07580639', '07580638', '07602583%2CT%2C007', '07932656', '07602583%2CT%2C007', '07932656', '07580638', '07580639', '07602583', '07580638', '07580638', '07580639', '07602583%2CT%2C007', '07602583%2CT%2C007', '07602583', '07602583%2CT%2C007', '07580638', '07932658', '07602583%2CT%2C007', '07520169%2CT%2C007', '07580639', '07520177', '07520169%2CT%2C006', '07580639', '07580638', '07580639', '07932656', '07501457%2CT%2C001', '07501457%2CT%2C002', '07501456%2CT%2C001', '07801713', '07801716', '07602278', '07602278', '07801718', '07801715', '07580658', '07873106', '07873109', '07873109', '70000117', '07873109', '70000127', '70000098', '07873107', '07873107', '07580658', '07873106', '07873109', '07932422', '70000098', '70000117', '70000127', '70000117', '07873109', '70000125', '07873107', '07580658', '07873109', '07873106', '07873106', '07580646', '07873109', '07873109', '07580658', '70000117', '07873106', '70000103', '70000127', '07873109', '70000098', '07873110', '07873106', '07580703', '07873106', '07873109', '70000127', '07873107', '07873109', '70000127', '70000103', '70000127', '07580656', '07873109', '07873106', '07580658', '07873107', '70000127', '07873106', '07580656', '07873107', '07580656', '07873109', '70000103', '07873106', '07873107', '07580646', '07580656', '07580703', '07932421', '70004878', '07873106', '07873106', '07873109', '70000127', '07580656', '07873109', '70000127', '07932424', '70000127', '70000127', '70000117', '07580658', '07580656', '07873109', '07580658', '70000098', '07580658', '07873106', '07580656', '07873109', '07873109', '07873106', '07873107', '70000117', '70000127', '07580658', '07873106', '70000117', '70000127', '07873106', '70000098', '07873106', '07873109', '70000127', '07580646', '70000125', '07580658', '70000127', '07873107', '07580658', '07580656', '07873107', '70000103', '07873107', '70000127', '07580656', '07873106', '70000103', '07580646', '70000117', '70000117', '07580656', '07580646', '70000127', '70000125', '07873107', '07580646', '70000127', '07873107', '70000127', '70000127', '07873109', '07580656', '70000127', '07873109', '70000125', '07873109', '07873109', '07873109', '07873107', '07873106', '07873106', '07580656', '07873107', '07580646', '07873109', '70000117', '07873106', '07873106', '07873109', '70000125', '70000117', '07873109', '07580658', '07580646', '07580646', '07580658', '07580656', '70000117', '70000127', '07873107', '70000125', '07873109', '70000103', '07873106', '07873109', '07873107', '07873106', '07580656', '70000117', '70004877', '70000117', '70000103', '70000117', '70004877', '07873109', '07873106', '07932427', '07873107', '07873107', '07873106', '70004877', '07580658', '07580646', '70000127', '07873107', '70000117', '70000103', '07873109', '70000127', '07873109', '70000117', '07873109', '07580646', '07873109', '07873106', '07873107', '07873106', '07873106', '07873109', '70004877', '07580646', '07580656', '07580658', '70000127', '07873107', '07580658', '07580658', '70000127', '70000103', '70000127', '07580656', '07580658', '07873109', '70000127', '70000127', '07580703', '07873109', '70000098', '07873109', '70000103', '07580658', '70000127', '07580703', '70000117', '07873109', '07580658', '70000125', '07580703', '70000098', '07873109', '70000127', '70000127', '07873106', '07873109', '07873106', '70000103', '07 ...

# %%
# now adding photgraphers to the network and connecting them with artworks
for k, v in photographer_dict.items():
    
    G.add_node(k, ent='photographer')
    weightDist = Counter(v)
    
    for work, wht in weightDist.items():
        G.add_node(work, ent='artwork')
        G.add_edge(k, work, weight=wht)

# %%
# updating node sets
artworks = {n for n, d in G.nodes(data=True) if d["ent"] == 'artwork'}
artists = {n for n, d in G.nodes(data=True) if d["ent"] == 'artist'}
photographers = {n for n, d in G.nodes(data=True) if d["ent"] == 'photographer'}

# %%
print(len(G.nodes()))
print(len(artworks)+len(artists)+len(photographers))
# Out:
# 66742
# 66742

# %%
### saving the whole network

# %%
nx.write_gexf(G,'networks/artist_artwork_photographer_whole.gexf')

# %% [markdown]
# ### Separate networks

# %% [markdown]
# #### Artwork – Photographers

# %%
B1 = nx.Graph()

for k, v in photographer_dict.items():
    
    B1.add_node(k, ent='photographer')
    weightDist = Counter(v)
    
    for work, wht in weightDist.items():
        B1.add_node(work, ent='artwork')
        B1.add_edge(k, work, weight=wht)

# %%
# Projecting the one-mode network
G1 = bipartite.weighted_projected_graph(B1, photographers)

# %%
nx.write_gexf(G1,'networks/cophotograph_artwork_whole.gexf')

# %%
### filtering nodes: decide type of filtering
filter_artists = []
for a in artists:
    if G1.degree(a) <= 10:
        filter_artists.append(a)
print(len(filter_artists))
print(len(artists)-len(filter_artists))
# Out:
# 4589
# 896

# %%
G1.remove_nodes_from(filter_artists)

# %%
# now, remove artworks without artists
filter_artworks = []
for w in artworks:
    if G1.degree(w) == 0:
        filter_artworks.append(w)
print(len(filter_artworks))
print(len(artworks)-len(filter_artworks))
# Out:
# 10548
# 41833

# %%
G1.remove_nodes_from(filter_artworks)

# %%
# now we can save any type of (filtered) network
nx.write_gexf(G1,'<filtered-network-filename>')

# %% [markdown]
# ## Testing area!

# %%
weights_test = []
for k, v in photographer_dict.items():
    
    weightDist = Counter(v)
    
    for work, wht in weightDist.items():
        weights_test.append(wht)

# %%
print(max(weights_test), min(weights_test))
# Out:
# 67 1
